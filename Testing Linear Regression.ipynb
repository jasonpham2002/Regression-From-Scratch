# %%
from main import LinearRegression
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv("Teen_Mental_Health_Dataset.csv")
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                      low             2              2                1
# 1                     high             8              1               10
# 2                     high             2              4                2
# 3                   medium             1              7                9
# 4                   medium             3              5                2
#
#    depression_label
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# Creating features  and prediction feature
y = df[['addiction_level']]
x = df.drop(['addiction_level'], axis=1)
x.head(100)
# Out:
#     age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0    14    male                       7.9      Instagram          7.4
# 1    19  female                       1.9         TikTok          8.0
# 2    17  female                       1.3      Instagram          7.6
# 3    15    male                       7.4         TikTok          6.9
# 4    15  female                       4.7           Both          4.9
# ..  ...     ...                       ...            ...          ...
# 95   15  female                       1.8      Instagram          6.4
# 96   13    male                       3.1         TikTok          5.4
# 97   13  female                       3.5         TikTok          5.2
# 98   18    male                       7.4         TikTok          6.4
# 99   16    male                       8.0      Instagram          5.5
#
#     screen_time_before_sleep  academic_performance  physical_activity  \
# 0                        2.9                  3.01                1.5
# 1                        2.9                  3.22                0.8
# 2                        0.5                  3.92                0.0
# 3                        1.6                  3.48                0.8
# 4                        3.0                  2.37                1.4
# ..                       ...                   ...                ...
# 95                       2.4                  2.16                1.9
# 96                       1.9                  3.66                0.4
# 97                       2.5                  2.57                1.1
# 98                       2.2                  3.51                1.0
# 99                       1.4                  2.95                0.3
#
#    social_interaction_level  stress_level  anxiety_level  depression_label
# 0                       low             2              2                 0
# 1                      high             8              1                 0
# 2                      high             2              4                 0
# 3                    medium             1              7                 0
# 4                    medium             3              5                 0
# ..                      ...           ...            ...               ...
# 95                   medium             3              6                 0
# 96                      low             7              4                 0
# 97                     high             1              6                 0
# 98                     high             4              5                 0
# 99                   medium             2              5                 0
#
# [100 rows x 12 columns]

# %%
# one hot encoding
x_cat = x[['gender','platform_usage','social_interaction_level']]
x_cat_encoded = pd.get_dummies(x_cat)
x_num = x.drop(x_cat, axis=1)

X= pd.concat([x_cat_encoded, x_num], axis=1)

X.head()
# Out:
#    gender_female  gender_male  platform_usage_Both  platform_usage_Instagram  \
# 0          False         True                False                      True
# 1           True        False                False                     False
# 2           True        False                False                      True
# 3          False         True                False                     False
# 4           True        False                 True                     False
#
#    platform_usage_TikTok  social_interaction_level_high  \
# 0                  False                          False
# 1                   True                           True
# 2                  False                           True
# 3                   True                          False
# 4                  False                          False
#
#    social_interaction_level_low  social_interaction_level_medium  age  \
# 0                          True                            False   14
# 1                         False                            False   19
# 2                         False                            False   17
# 3                         False                             True   15
# 4                         False                             True   15
#
#    daily_social_media_hours  sleep_hours  screen_time_before_sleep  \
# 0                       7.9          7.4                       2.9
# 1                       1.9          8.0                       2.9
# 2                       1.3          7.6                       0.5
# 3                       7.4          6.9                       1.6
# 4                       4.7          4.9                       3.0
#
#    academic_performance  physical_activity  stress_level  anxiety_level  \
# 0                  3.01                1.5             2              2
# 1                  3.22                0.8             8              1
# 2                  3.92                0.0             2              4
# 3                  3.48                0.8             1              7
# 4                  2.37                1.4             3              5
#
#    depression_label
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
ln_reg  = LinearRegression()

ln_reg.fit(X,y)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[37], line 3
#       1 ln_reg  = LinearRegression()
#       2
# ----> 3 ln_reg.fit(X,y)
#
# File ~\PycharmProjects\ML_Projects\main.py:43, in LinearRegression.fit(self, X, y)
#      40 #initializae w
#      41 self.w = np.zeros((n,1))
# ---> 43 self.gradient_descent(self.compute_gradient, X, y, self.lr, self.n_iters, self.compute_cost)
#
# File ~\PycharmProjects\ML_Projects\main.py:30, in LinearRegression.gradient_descent(self, compute_gradient, X, y, alpha, iters, compute_cost)
#      28 for i in range(iters):
#      29     self.w = self.w - alpha * compute_gradient(X,y)
# ---> 30     cost =  compute_cost(X,y)
#      31     self.cost_history.append(cost)
#
# File ~\PycharmProjects\ML_Projects\main.py:14, in LinearRegression.compute_cost(self, X, y)
#      12 m = X.shape[0]
#      13 y_hat = X @ self.w
# ---> 14 j = 1 / (2 * m) * np.sum((y_hat - y) ** 2)
#      15 return j
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:246, in OpsMixin.__pow__(self, other)
#     244 @unpack_zerodim_and_defer("__pow__")
#     245 def __pow__(self, other):
# --> 246     return self._arith_method(other, operator.pow)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9151, in DataFrame._arith_method(self, other, op)
#    9147
#    9148         self, other = self._align_for_op(other, axis, flex=True, level=None)
#    9149
#    9150         with np.errstate(all="ignore"):
# -> 9151             new_data = self._dispatch_frame_op(other, op, axis=axis)
#    9152         return self._construct_result(new_data, other=other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9179
#    9180         right = lib.item_from_zerodim(right)
#    9181         if not is_list_like(right):
#    9182             # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 9183             bm = self._mgr.apply(array_op, right=right)
#    9184             return self._constructor_from_mgr(bm, axes=bm.axes)
#    9185
#    9186         elif isinstance(right, DataFrame):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:443, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440             kwargs[k] = obj[b.mgr_locs.indexer]
#     442 if callable(f):
# --> 443     applied = b.apply(f, **kwargs)
#     444 else:
#     445     applied = getattr(b, f)(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:289, in arithmetic_op(left, right, op)
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     287     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     288     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 289     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     291 return res_values
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     217     func = partial(expressions.evaluate, op)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)    227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:252, in evaluate(op, left_op, right_op, use_numexpr)
#     249 if op_str is not None:
#     250     if use_numexpr:
#     251         # error: "None" not callable
# --> 252         return _evaluate(op, op_str, left_op, right_op)  # type: ignore[misc]
#     253 return _evaluate_standard(op, op_str, left_op, right_op)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:83, in _evaluate_standard(op, op_str, left_op, right_op)
#      81 if _TEST_MODE:
#      82     _store_test_result(False)
# ---> 83 return op(left_op, right_op)
#
# OverflowError: (34, 'Result too large')

# %%
x_cat_encoded.head(100)
# print(x_cat_encoded.shape)
# print(x_num.shape)
# print(X.shape)
